# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# This file should produce two dataframes for EACH GAME. One should be the overall team performance, with metrics like:
# The other should be individual player performance, with metrics like:

# %% [markdown]
# ## Imports

# %%
import json
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
with open('data/problem.json', 'r', encoding='utf-8') as f:
    raw_data = json.load(f)
raw_data = pd.DataFrame(raw_data)

# %%
raw_data.head()
# Out:
#                              platformGameId  \
# 0  val:036fd228-98cb-4fea-a3d5-c770b3d89c87
# 1  val:036fd228-98cb-4fea-a3d5-c770b3d89c87
# 2  val:036fd228-98cb-4fea-a3d5-c770b3d89c87
# 3  val:036fd228-98cb-4fea-a3d5-c770b3d89c87
# 4  val:036fd228-98cb-4fea-a3d5-c770b3d89c87
#
#                                             metadata  \
# 0  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 1  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 2  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 3  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 4  {'serverInfo': {'processId': '', 'rfc190Scope'...
#
#                                             snapshot  \
# 0  {'observers': [{'displayName': 'VCTobs5', 'obs...
# 1                                                NaN
# 2  {'observers': [{'displayName': 'VCTobs5', 'obs...
# 3  {'observers': [{'displayName': 'VCTobs5', 'obs...
# 4  {'observers': [{'displayName': 'VCTobs5', 'obs...
#
#                                        configuration gamePhase playerSpawn  \
# 0                                                NaN       NaN         NaN
# 1  {'teams': [{'teamId': {'value': 21}, 'playersI...       NaN         NaN
# 2                                                NaN       NaN         NaN
# 3                                                NaN       NaN         NaN
# 4                                                NaN       NaN         NaN
#
#   roundStarted spikeStatus observerTarget inventoryTransaction  ...  \
# 0          NaN         NaN            NaN                  NaN  ...
# 1          NaN         NaN            NaN                  NaN  ...
# 2          NaN         NaN            NaN                  NaN  ...
# 3          NaN         NaN            NaN                  NaN  ...
# 4          NaN         NaN            NaN                  NaN  ...
#
#   spikePlantStarted spikePlantCompleted spikeDefuseStarted spikeDefuseStopped  \
# 0               NaN                 NaN                NaN                NaN
# 1               NaN                 NaN                NaN                NaN
# 2               NaN                 NaN                NaN                NaN
# 3               NaN                 NaN                NaN                NaN
# 4               NaN                 NaN                NaN                NaN
#
#   spikeDefuseCheckpointReached roundDecided roundCeremony roundEnded  \
# 0                          NaN          NaN           NaN        NaN
# 1                          NaN          NaN           NaN        NaN
# 2                          NaN          NaN           NaN        NaN
# 3                          NaN          NaN           NaN        NaN
# 4                          NaN          NaN           NaN        NaN
#
#   spikePlantStopped gameDecided
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
#
# [5 rows x 23 columns]

# %%
filtered_df
# Out:
#                                 platformGameId snapshot  \
# 1     val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 12    val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 76    val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 98    val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 119   val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# ...                                        ...      ...
# 6785  val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 6807  val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 6836  val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 6988  val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
# 7024  val:0281bb56-6d4f-4ccc-946e-b40467fbe2e8      NaN
#
#                                                metadata  \
# 1     {'serverInfo': {'processId': '', 'rfc190Scope'...
# 12    {'serverInfo': {'processId': '', 'rfc190Scope'...
# 76    {'serverInfo': {'processId': '', 'rfc190Scope'...
# 98    {'serverInfo': {'processId': '', 'rfc190Scope'...
# 119   {'serverInfo': {'processId': '', 'rfc190Scope'...
# ...                                                 ...
# 6785  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 6807  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 6836  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 6988  {'serverInfo': {'processId': '', 'rfc190Scope'...
# 7024  {'serverInfo': {'processId': '', 'rfc190Scope'...
#
#                                           configuration gamePhase playerSpawn  \
# 1     {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 12    {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 76    {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 98    {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 119   {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# ...                                                 ...       ...         ...
# 6785  {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 6807  {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 6836  {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 6988  {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
# 7024  {'teams': [{'teamId': {'value': 18}, 'playersI...       NaN         NaN
#
#      roundStarted spikeStatus observerTarget inventoryTransaction  ...  \
# 1             NaN         NaN            NaN                  NaN  ...
# 12            NaN         NaN            NaN                  NaN  ...
# 76            NaN         NaN            NaN                  NaN  ...
# 98            NaN         NaN            NaN                  NaN  ...
# 119           NaN         NaN            NaN                  NaN  ...
# ...           ...         ...            ...                  ...  ...
# 6785          NaN         NaN            NaN                  NaN  ...
# 6807          NaN         NaN            NaN                  NaN  ...
# 6836          NaN         NaN            NaN                  NaN  ...
# 6988          NaN         NaN            NaN                  NaN  ...
# 7024          NaN         NaN            NaN                  NaN  ...
#
#      roundDecided roundCeremony roundEnded spikePlantStarted  \
# 1             NaN           NaN        NaN               NaN
# 12            NaN           NaN        NaN               NaN
# 76            NaN           NaN        NaN               NaN
# 98            NaN           NaN        NaN               NaN
# 119           NaN           NaN        NaN               NaN
# ...           ...           ...        ...               ...
# 6785          NaN           NaN        NaN               NaN
# 6807          NaN           NaN        NaN               NaN
# 6836          NaN           NaN        NaN               NaN
# 6988          NaN           NaN        NaN               NaN
# 7024          NaN           NaN        NaN               NaN
#
#      spikePlantStopped spikePlantCompleted spikeDefuseStarted  \
# 1                  NaN                 NaN                NaN
# 12                 NaN                 NaN                NaN
# 76                 NaN                 NaN                NaN
# 98                 NaN                 NaN                NaN
# 119                NaN                 NaN                NaN
# ...                ...                 ...                ...
# 6785               NaN                 NaN                NaN
# 6807               NaN                 NaN                NaN
# 6836               NaN                 NaN                NaN
# 6988               NaN                 NaN                NaN
# 7024               NaN                 NaN                NaN
#
#      spikeDefuseCheckpointReached spikeDefuseStopped gameDecided
# 1                             NaN                NaN         NaN
# 12                            NaN                NaN         NaN
# 76                            NaN                NaN         NaN
# 98                            NaN                NaN         NaN
# 119                           NaN                NaN         NaN
# ...                           ...                ...         ...
# 6785                          NaN                NaN         NaN
# 6807                          NaN                NaN         NaN
# 6836                          NaN                NaN         NaN
# 6988                          NaN                NaN         NaN
# 7024                          NaN                NaN         NaN
#
# [293 rows x 23 columns]

# %% [markdown]
# ## Rounds Dictionary

# %%
# Filter rows where roundStarted or roundEnded are not NaN
filtered_df = raw_data[(pd.notna(raw_data['roundStarted'])) | (pd.notna(raw_data['roundEnded']))]

rounds_dict = {}

# Loop through the filtered DataFrame
for index, row in filtered_df.iterrows():
    # Check if the round has started
    if pd.notna(row['roundStarted']):
        round_number = row['roundStarted'].get('roundNumber')
        if round_number:
            rounds_dict[round_number] = {'start_index': index, 'end_index': None}
    
    # Check if the round has ended
    if pd.notna(row['roundEnded']):
        round_number = row['roundEnded'].get('roundNumber')
        if round_number in rounds_dict:
            rounds_dict[round_number]['end_index'] = index

# Remove rounds that don't have both start and end indices
rounds_dict = {k: v for k, v in rounds_dict.items() if v['end_index'] is not None}

# Now rounds_dict will contain the start and end index for each round
print(rounds_dict)
# Out:
# {1: {'start_index': 25, 'end_index': 818}, 2: {'start_index': 868, 'end_index': 1174}, 3: {'start_index': 1198, 'end_index': 1605}, 4: {'start_index': 1633, 'end_index': 2027}, 5: {'start_index': 2048, 'end_index': 2486}, 6: {'start_index': 2512, 'end_index': 2910}, 7: {'start_index': 2934, 'end_index': 3376}, 8: {'start_index': 3401, 'end_index': 3745}, 9: {'start_index': 3770, 'end_index': 4213}, 10: {'start_index': 4234, 'end_index': 4617}, 11: {'start_index': 4643, 'end_index': 5016}, 12: {'start_index': 5039, 'end_index': 5355}, 13: {'start_index': 5417, 'end_index': 5864}, 14: {'start_index': 5887, 'end_index': 6268}, 15: {'start_index': 6291, 'end_index': 6657}, 16: {'start_index': 6681, 'end_index': 6987}, 17: {'start_index': 7011, 'end_index': 7397}, 18: {'start_index': 7421, 'end_index': 7886}, 19: {'start_index': 7914, 'end_index': 8229}, 20: {'start_index': 8253, 'end_index': 8829}, 21: {'start_index': 8852, 'end_index': 9455}, 22: {'start_index': 9477, 'end_index': 9810}, 23: {'start_index': 9836, 'end_index': 10134}, 24: {'start_index': 10157, 'end_index': 10537}, 25: {'start_index': 10599, 'end_index': 11102}}

# %% [markdown]
# ## team_pf & round_df

# %%
winlossdata = raw_data['gameDecided'].dropna().values[0]

# Extract the first round's teams
first_round = winlossdata['spikeMode']['completedRounds'][0]
team_1_number = first_round['spikeModeResult']['attackingTeam']['value']
team_2_number = first_round['spikeModeResult']['defendingTeam']['value']

# Initialize cumulative metrics using Python lists
team_1_metrics = {'Team': team_1_number, 'Total Wins': 0, 'Attacking Half Wins': 0, 'Defending Half Wins': 0, 'Pistol Round Wins': 0}
team_2_metrics = {'Team': team_2_number, 'Total Wins': 0, 'Attacking Half Wins': 0, 'Defending Half Wins': 0, 'Pistol Round Wins': 0}

# Loop through the rounds to calculate cumulative metrics
for round_info in winlossdata['spikeMode']['completedRounds']:
    round_number = round_info['roundNumber']
    winning_team = round_info['winningTeam']['value']
    attacking_team = round_info['spikeModeResult']['attackingTeam']['value']
    defending_team = round_info['spikeModeResult']['defendingTeam']['value']

    # Determine if the round was won while attacking or defending
    if winning_team == attacking_team:
        if winning_team == team_1_number:
            team_1_metrics['Attacking Half Wins'] += 1
        else:
            team_2_metrics['Attacking Half Wins'] += 1
    elif winning_team == defending_team:
        if winning_team == team_1_number:
            team_1_metrics['Defending Half Wins'] += 1
        else:
            team_2_metrics['Defending Half Wins'] += 1

    # Increment total wins for the winning team
    if winning_team == team_1_number:
        team_1_metrics['Total Wins'] += 1
    else:
        team_2_metrics['Total Wins'] += 1

    # Check if it's a pistol round (round 1 or round 13)
    if round_number == 1 or round_number == 13:
        if winning_team == team_1_number:
            team_1_metrics['Pistol Round Wins'] += 1
        else:
            team_2_metrics['Pistol Round Wins'] += 1

# Combine metrics for both teams into a list
all_team_metrics = [team_1_metrics, team_2_metrics]

# Convert the list of dictionaries into a DataFrame
team_pf = pd.DataFrame(all_team_metrics)

# %%
# Initialize lists to hold the round number and winning team information
round_numbers = []
winning_teams = []

# Loop through the rounds to calculate cumulative metrics and build the round_df
for round_info in winlossdata['spikeMode']['completedRounds']:
    round_number = round_info['roundNumber']
    winning_team = round_info['winningTeam']['value']
    
    # Add the round number and winning team to their respective lists
    round_numbers.append(round_number)
    winning_teams.append(winning_team)

    # Determine if the round was won while attacking or defending
    attacking_team = round_info['spikeModeResult']['attackingTeam']['value']
    defending_team = round_info['spikeModeResult']['defendingTeam']['value']
    
    if winning_team == attacking_team:
        if winning_team == team_1_number:
            team_1_metrics['Attacking Half Wins'] += 1
        else:
            team_2_metrics['Attacking Half Wins'] += 1
    elif winning_team == defending_team:
        if winning_team == team_1_number:
            team_1_metrics['Defending Half Wins'] += 1
        else:
            team_2_metrics['Defending Half Wins'] += 1

    # Increment total wins for the winning team
    if winning_team == team_1_number:
        team_1_metrics['Total Wins'] += 1
    else:
        team_2_metrics['Total Wins'] += 1

    # Check if it's a pistol round (round 1 or round 13)
    if round_number == 1 or round_number == 13:
        if winning_team == team_1_number:
            team_1_metrics['Pistol Round Wins'] += 1
        else:
            team_2_metrics['Pistol Round Wins'] += 1

# Combine the round numbers and winning teams into a DataFrame
round_df = pd.DataFrame({
    'Round Number': round_numbers,
    'Winning Team': winning_teams
})

# Set the index to the round number
round_df.set_index('Round Number', inplace=True)

# Combine metrics for both teams into a list and convert it into a DataFrame
all_team_metrics = [team_1_metrics, team_2_metrics]
team_pf = pd.DataFrame(all_team_metrics)

# %%
round_df
# Out:
#               Winning Team
# Round Number
# 1                       22
# 2                       22
# 3                       22
# 4                       21
# 5                       21
# 6                       22
# 7                       21
# 8                       21
# 9                       22
# 10                      21
# 11                      21
# 12                      22
# 13                      22
# 14                      22
# 15                      21
# 16                      21
# 17                      21
# 18                      21
# 19                      21
# 20                      22
# 21                      22
# 22                      21
# 23                      22
# 24                      22
# 25                      21
# 26                      21

# %%
team_pf
# Out:
#    Team  Total Wins  Attacking Half Wins  Defending Half Wins  \
# 0    21          28                   14                   14
# 1    22          24                   12                   12
#
#    Pistol Round Wins
# 0                  0
# 1                  4

# %% [markdown]
# ## Round_df and RoundCeremony

# %%
# Initialize an empty list for the round ceremony types
round_ceremony_types = []

# Extract round ceremonies (assuming the order aligns with round numbers)
round_ceremony = raw_data['roundCeremony'].dropna()

# Loop through the available round ceremonies
for idx, round_info in enumerate(round_df.index):
    # Check if there is a corresponding round ceremony and extract the type
    if idx < len(round_ceremony):
        ceremony = round_ceremony.iloc[idx]
        ceremony_type = ceremony.get('type', 'UNKNOWN')  # Default to 'UNKNOWN' if type is missing
        round_ceremony_types.append(ceremony_type)
    else:
        round_ceremony_types.append(None)  # Append None if no ceremony data is available

# Add the extracted round ceremony types to round_df
round_df['Round Ceremony Type'] = round_ceremony_types

# %%
round_df
# Out:
#               Winning Team Round Ceremony Type
# Round Number
# 1                       22             DEFAULT
# 2                       22                 ACE
# 3                       22             DEFAULT
# 4                       21             THRIFTY
# 5                       21             DEFAULT
# 6                       22             DEFAULT
# 7                       21              CLUTCH
# 8                       21             DEFAULT
# 9                       22             DEFAULT
# 10                      21             DEFAULT
# 11                      21             DEFAULT
# 12                      22             DEFAULT
# 13                      22             DEFAULT
# 14                      22             DEFAULT
# 15                      21             DEFAULT
# 16                      21             DEFAULT
# 17                      21             DEFAULT
# 18                      21             DEFAULT
# 19                      21             DEFAULT
# 20                      22             DEFAULT
# 21                      22             DEFAULT
# 22                      21             DEFAULT
# 23                      22             DEFAULT
# 24                      22            FLAWLESS
# 25                      21            TEAM_ACE
# 26                      21             DEFAULT

# %%
team_pf
# Out:
#    Team  Total Wins  Attacking Half Wins  Defending Half Wins  \
# 0    21          28                   14                   14
# 1    22          24                   12                   12
#
#    Pistol Round Wins
# 0                  0
# 1                  4

# %% [markdown]
# ## player_pf

# %%
# Initialize a dictionary to store player stats
player_metrics = {}

# Iterate over rounds_dict to extract relevant damage events and calculate metrics
for round_number, indices in rounds_dict.items():
    start_index = indices['start_index']
    end_index = indices['end_index']
    
    # Filter the rows of damage events within the round using vectorized indexing
    round_damage_events = raw_data.loc[start_index:end_index, 'damageEvent'].dropna()

    # Process each damage event and directly update player stats
    for event in round_damage_events:
        print(event)
        causer_id = event['causerId']['value']
        victim_id = event['victimId']['value']
        damage_amount = event['damageAmount']
        kill_event = event['killEvent']
        location = event['location']

        # Initialize or update stats for causer (the one dealing damage)
        if causer_id not in player_metrics:
            player_metrics[causer_id] = {
                'kills': 0, 'deaths': 0, 'damage_dealt': 0, 'damage_taken': 0, 'total_hits': 0, 'headshots': 0
            }

        # Initialize or update stats for victim (the one receiving damage)
        if victim_id not in player_metrics:
            player_metrics[victim_id] = {
                'kills': 0, 'deaths': 0, 'damage_dealt': 0, 'damage_taken': 0, 'total_hits': 0, 'headshots': 0
            }

        # Update causer's stats
        player_metrics[causer_id]['damage_dealt'] += damage_amount
        player_metrics[causer_id]['total_hits'] += 1
        
        if location == 'HEAD':
            player_metrics[causer_id]['headshots'] += 1

        if kill_event:
            player_metrics[causer_id]['kills'] += 1

        # Update victim's stats
        player_metrics[victim_id]['damage_taken'] += damage_amount
        if kill_event:
            player_metrics[victim_id]['deaths'] += 1

# Calculate headshot percentage for each player
for player_id, metrics in player_metrics.items():
    total_hits = metrics['total_hits']
    headshots = metrics['headshots']
    metrics['headshot_percentage'] = (headshots / total_hits * 100) if total_hits > 0 else 0

# Convert the player_metrics dictionary into a DataFrame for analysis
player_pf = pd.DataFrame.from_dict(player_metrics, orient='index').reset_index()
player_pf.rename(columns={'index': 'playerID'}, inplace=True)
# Out:
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 7}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': True, 'damageDealt': 105, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}, 'type': 'UNKNOWN'}, 'damageAmount': 100}
# {'location': 'GENERAL', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 12, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Pandemic_Decay_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 1}, 'damageAmount': 12}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 8}, 'killEvent': True, 'damageDealt': 63, 'victimId': {'value': 1}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}}, 'damageAmount': 62}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 4}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 4}, 'weapon': {'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 4}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 8}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 4}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': True, 'damageDealt': 26, 'victimId': {'value': 4}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}}, 'damageAmount': 22}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 21, 'victimId': {'value': 5}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}}, 'damageAmount': 21}
# {'location': 'BODY', 'wallPen': True, 'causerId': {'value': 5}, 'killEvent': False, 'damageDealt': 15.7884417, 'victimId': {'value': 8}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}}, 'damageAmount': 15.7884407}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 21, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 21}
# {'location': 'BODY', 'wallPen': True, 'causerId': {'value': 5}, 'killEvent': False, 'damageDealt': 11.3267345, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}, 'type': 'UNKNOWN'}, 'damageAmount': 11.3267345}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 6}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'wallPen': True, 'causerId': {'value': 6}, 'killEvent': False, 'damageDealt': 12.121707, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 12.121707}
# {'location': 'HEAD', 'causerId': {'value': 6}, 'wallPen': True, 'killEvent': False, 'damageDealt': 55.2404938, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 55.2404938}
# {'location': 'BODY', 'causerId': {'value': 5}, 'wallPen': False, 'killEvent': False, 'damageDealt': 30, 'victimId': {'value': 6}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E', 'inventorySlot': {'slot': 'SECONDARY'}}}, 'damageAmount': 30}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 6}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'HEAD', 'causerId': {'value': 5}, 'wallPen': False, 'killEvent': True, 'damageDealt': 105, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}, 'type': 'UNKNOWN'}, 'damageAmount': 58.6732635}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 78, 'victimId': {'value': 9}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8'}}, 'damageAmount': 78}
# {'location': 'HEAD', 'causerId': {'value': 9}, 'wallPen': False, 'killEvent': False, 'damageDealt': 105, 'victimId': {'value': 2}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E', 'inventorySlot': {'slot': 'SECONDARY'}}}, 'damageAmount': 105}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': True, 'damageDealt': 25, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 22}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': True, 'damageDealt': 26, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 6.63779831}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': True, 'damageDealt': 78, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 6.2115593}
# {'location': 'BODY', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': True, 'damageDealt': 26, 'victimId': {'value': 2}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 20}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 5}, 'killEvent': False, 'damageDealt': 30, 'victimId': {'value': 10}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}}, 'damageAmount': 30}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 5}, 'killEvent': False, 'damageDealt': 30, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}, 'type': 'UNKNOWN'}, 'damageAmount': 30}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 10}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 5}, 'wallPen': False, 'killEvent': False, 'damageDealt': 30, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}, 'type': 'UNKNOWN'}, 'damageAmount': 30}
# {'location': 'HEAD', 'causerId': {'value': 5}, 'wallPen': False, 'killEvent': True, 'damageDealt': 105, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E'}, 'type': 'UNKNOWN'}, 'damageAmount': 10}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': True, 'killEvent': False, 'damageDealt': 22.7055111, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7'}, 'type': 'UNKNOWN'}, 'damageAmount': 22.7055111}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 27, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 27}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 6}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 2}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8'}}, 'damageAmount': 26}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 6}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 6}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 6}, 'damageAmount': 1}
# {'location': 'HEAD', 'wallPen': True, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 48.2998161, 'victimId': {'value': 7}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 48.2998161}
# {'location': 'BODY', 'wallPen': True, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 10.8609285, 'victimId': {'value': 7}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7'}}, 'damageAmount': 10.8609285}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 7}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 26}
# {'location': 'LEG', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': True, 'damageDealt': 22.1, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 14.8392563}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': True, 'damageDealt': 78, 'victimId': {'value': 10}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 74}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 9}, 'killEvent': False, 'damageDealt': 78, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 78}
# {'location': 'HEAD', 'causerId': {'value': 3}, 'wallPen': False, 'killEvent': False, 'damageDealt': 67.5, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 67.5}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': False, 'damageDealt': 27, 'victimId': {'value': 9}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}}, 'damageAmount': 27}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 9}, 'killEvent': True, 'damageDealt': 78, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 72}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': True, 'damageDealt': 22, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 21.294487}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 9}, 'killEvent': False, 'damageDealt': 21, 'victimId': {'value': 1}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}}, 'damageAmount': 21}
# {'location': 'BODY', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 8}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7'}}, 'damageAmount': 26}
# {'location': 'BODY', 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '29A0CFAB-485B-F5D5-779A-B59F85E204A8'}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 26}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': True, 'damageDealt': 78, 'victimId': {'value': 8}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7'}, 'type': 'UNKNOWN'}, 'damageAmount': 47}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 9}, 'killEvent': False, 'damageDealt': 26, 'victimId': {'value': 1}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}}, 'damageAmount': 26}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': True, 'damageDealt': 78, 'victimId': {'value': 9}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '462080D1-4035-2937-7C09-27AA2A5C27A7'}}, 'damageAmount': 5.5}
# {'location': 'HEAD', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'ULTIMATE'}, 'guid': 'ADD6443A-41BD-E414-F6AD-E58D267F4E95'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': True, 'damageDealt': 150, 'victimId': {'value': 8}, 'damageAmount': 125}
# {'location': 'BODY', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 23}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 6}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 23}
# {'location': 'BODY', 'causerId': {'value': 6}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 2}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 23}
# {'location': 'BODY', 'causerId': {'value': 6}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 2}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 6}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}}, 'damageAmount': 23}
# {'location': 'BODY', 'causerId': {'value': 6}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 2}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'HEAD', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 57.5, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 57.5}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': True, 'damageDealt': 57.5, 'victimId': {'value': 6}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 0.499996185}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': False, 'damageDealt': 40, 'victimId': {'value': 10}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}}, 'damageAmount': 40}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 7}, 'killEvent': False, 'damageDealt': 6, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'MELEE'}, 'guid': ''}, 'type': 'UNKNOWN'}, 'damageAmount': 6}
# {'location': 'HEAD', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 6, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'MELEE'}, 'guid': ''}, 'type': 'UNKNOWN'}, 'damageAmount': 6}
# {'location': 'BODY', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'ULTIMATE'}, 'guid': 'ADD6443A-41BD-E414-F6AD-E58D267F4E95'}}, 'causerId': {'value': 1}, 'killEvent': False, 'wallPen': False, 'damageDealt': 50, 'victimId': {'value': 9}, 'damageAmount': 50}
# {'location': 'GENERAL', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': False, 'damageDealt': 20.0433407, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_FallDamage_C'}, 'type': 'FALL'}, 'victimId': {'value': 1}, 'damageAmount': 20.0433407}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 7}, 'killEvent': False, 'damageDealt': 39, 'victimId': {'value': 1}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}}, 'damageAmount': 39}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 39, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 39}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 39, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 39}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '5F8D3A7F-467B-97F3-062C-13ACF203C006'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 60, 'victimId': {'value': 10}, 'damageAmount': 60}
# {'location': 'LEG', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 22.95, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 22.95}
# {'location': 'LEG', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 22.95, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 22.95}
# {'location': 'BODY', 'causerId': {'value': 5}, 'wallPen': True, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'LEG', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': True, 'damageDealt': 22.95, 'victimId': {'value': 9}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 19.0999947}
# {'location': 'LEG', 'wallPen': False, 'causerId': {'value': 7}, 'killEvent': True, 'damageDealt': 29.75, 'victimId': {'value': 1}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 0.95665741}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 6, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'MELEE'}, 'guid': ''}, 'type': 'UNKNOWN'}, 'damageAmount': 6}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 6, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'MELEE'}, 'guid': ''}, 'type': 'UNKNOWN'}, 'damageAmount': 6}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 39, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 39}
# {'location': 'HEAD', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': True, 'damageDealt': 160, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 99}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 27, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 27}
# {'location': 'HEAD', 'wallPen': False, 'causerId': {'value': 10}, 'killEvent': True, 'damageDealt': 160, 'victimId': {'value': 2}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}}, 'damageAmount': 27.6658058}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': True, 'damageDealt': 35, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 23}
# {'location': 'GENERAL', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 19.0675182, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_FallDamage_C'}, 'type': 'FALL'}, 'victimId': {'value': 4}, 'damageAmount': 19.0675182}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': False, 'damageDealt': 7.8605361, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Hunter_4_Molotov_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 4}, 'damageAmount': 7.86053658}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': False, 'damageDealt': 16.0391636, 'hazard': {'type': 'FALL', 'fallback': {'guid': '', 'displayName': 'DmgType_FallDamage_C'}}, 'victimId': {'value': 3}, 'damageAmount': 16.0391636}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 7}, 'killEvent': False, 'damageDealt': 39, 'victimId': {'value': 3}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 39}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 39, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 39}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': True, 'damageDealt': 39, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 30.9608383}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7'}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7'}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 4}, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7'}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': False, 'killEvent': True, 'damageDealt': 35, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'AE3DE142-4D85-2547-DD26-4E90BED35CF7'}, 'type': 'UNKNOWN'}, 'damageAmount': 10.0000076}
# {'location': 'BODY', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'HEAD', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': True, 'damageDealt': 159.5, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'guid': 'E336C6B8-418D-9340-D77F-7A9E4CFE0702', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 150}
# {'location': 'LEG', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': False, 'damageDealt': 34, 'victimId': {'value': 10}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}}, 'damageAmount': 34}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '1E58DE9C-4950-5125-93E9-A0AEE9F98746'}}, 'causerId': {'value': 2}, 'killEvent': False, 'wallPen': False, 'damageDealt': 1, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'type': 'UNIMPLEMENTED', 'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'type': 'UNIMPLEMENTED', 'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 1, 'hazard': {'type': 'UNIMPLEMENTED', 'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 1, 'hazard': {'type': 'UNIMPLEMENTED', 'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 1, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Killjoy_4_Bees_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 1}
# ...
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'BODY', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 6, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'MELEE'}, 'guid': ''}, 'type': 'UNKNOWN'}, 'damageAmount': 6}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}}, 'causerId': {'value': 8}, 'killEvent': False, 'wallPen': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}, 'guid': '707EAB51-4836-F488-046A-CDA6BF494859'}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'GENERAL', 'ability': {'fallback': {'displayName': '', 'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'inventorySlot': {'slot': 'GRENADE_ABILITY'}}, 'type': 'UNKNOWN'}, 'causerId': {'value': 8}, 'wallPen': False, 'killEvent': False, 'damageDealt': 2, 'victimId': {'value': 2}, 'damageAmount': 2}
# {'location': 'BODY', 'causerId': {'value': 7}, 'wallPen': False, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 5}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 23}
# {'location': 'HEAD', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': True, 'damageDealt': 160, 'victimId': {'value': 7}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 125}
# {'location': 'LEG', 'causerId': {'value': 10}, 'wallPen': True, 'killEvent': False, 'damageDealt': 16.3116608, 'victimId': {'value': 3}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 16.3116608}
# {'location': 'HEAD', 'causerId': {'value': 10}, 'wallPen': True, 'killEvent': True, 'damageDealt': 84.6026764, 'victimId': {'value': 3}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 83.6883392}
# {'location': 'LEG', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': False, 'damageDealt': 29.75, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 29.75}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 8}, 'killEvent': False, 'damageDealt': 18.5, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Pandemic_Decay_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 5}, 'damageAmount': 18.5}
# {'location': 'LEG', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': True, 'damageDealt': 29.75, 'victimId': {'value': 5}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 28.75}
# {'location': 'BODY', 'causerId': {'value': 9}, 'wallPen': False, 'killEvent': False, 'damageDealt': 40, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 40}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 9}, 'killEvent': False, 'damageDealt': 40, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 40}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 1}, 'killEvent': False, 'damageDealt': 40, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 40}
# {'location': 'HEAD', 'causerId': {'value': 1}, 'wallPen': False, 'killEvent': True, 'damageDealt': 160, 'victimId': {'value': 9}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 110}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 2}, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941'}, 'type': 'UNKNOWN'}, 'damageAmount': 23}
# {'location': 'BODY', 'causerId': {'value': 2}, 'wallPen': False, 'killEvent': False, 'damageDealt': 23, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': 'F7E1B454-4AD4-1063-EC0A-159E56B58941', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 23}
# {'location': 'BODY', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 2}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}}, 'damageAmount': 35}
# {'location': 'BODY', 'causerId': {'value': 10}, 'wallPen': False, 'killEvent': True, 'damageDealt': 35, 'victimId': {'value': 2}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}}, 'damageAmount': 23.999939}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 10}, 'killEvent': False, 'damageDealt': 35, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A', 'inventorySlot': {'slot': 'PRIMARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 35}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 10}, 'killEvent': True, 'damageDealt': 39, 'victimId': {'value': 1}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': 'EE8E8D15-496B-07AC-E5F6-8FAE5D4C7B1A'}, 'type': 'UNKNOWN'}, 'damageAmount': 10}
# {'location': 'BODY', 'wallPen': True, 'causerId': {'value': 4}, 'killEvent': False, 'damageDealt': 11.5570345, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 11.5570345}
# {'location': 'BODY', 'wallPen': True, 'causerId': {'value': 4}, 'killEvent': False, 'damageDealt': 9.96383858, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 9.96383858}
# {'location': 'BODY', 'causerId': {'value': 4}, 'wallPen': True, 'killEvent': False, 'damageDealt': 11.6859732, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3', 'inventorySlot': {'slot': 'SECONDARY'}}, 'type': 'UNKNOWN'}, 'damageAmount': 11.6859732}
# {'location': 'HEAD', 'causerId': {'value': 4}, 'wallPen': True, 'killEvent': False, 'damageDealt': 44.5563431, 'victimId': {'value': 10}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}, 'type': 'UNKNOWN'}, 'damageAmount': 44.5563431}
# {'location': 'BODY', 'wallPen': False, 'causerId': {'value': 4}, 'killEvent': True, 'damageDealt': 26, 'victimId': {'value': 10}, 'weapon': {'type': 'UNKNOWN', 'fallback': {'displayName': '', 'inventorySlot': {'slot': 'SECONDARY'}, 'guid': '44D4E95C-4157-0037-81B2-17841BF2E8E3'}}, 'damageAmount': 8.23680878}
# {'location': 'HEAD', 'causerId': {'value': 6}, 'wallPen': False, 'killEvent': True, 'damageDealt': 160, 'victimId': {'value': 4}, 'weapon': {'fallback': {'displayName': '', 'inventorySlot': {'slot': 'PRIMARY'}, 'guid': '9C82E19D-4575-0200-1A81-3EACF00CF872'}, 'type': 'UNKNOWN'}, 'damageAmount': 125}
# {'location': 'GENERAL', 'wallPen': False, 'causerId': {'value': 3}, 'killEvent': False, 'damageDealt': 34.3028, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Hunter_4_Molotov_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 9}, 'damageAmount': 34.3028}
# {'location': 'GENERAL', 'wallPen': False, 'killEvent': False, 'damageDealt': 37.3460579, 'hazard': {'fallback': {'guid': '', 'displayName': 'DmgType_Hunter_4_Molotov_C'}, 'type': 'UNIMPLEMENTED'}, 'victimId': {'value': 6}, 'damageAmount': 37.3460579}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 15
#      13 for event in round_damage_events:
#      14     print(event)
# ---> 15     causer_id = event['causerId']['value']
#      16     victim_id = event['victimId']['value']
#      17     damage_amount = event['damageAmount']
#
# KeyError: 'causerId'

# %%
final_row = raw_data[raw_data['snapshot'].notna()].iloc[-1]

# %%
# Iterate through playertest['players'] and update player_metrics_df
for player in final_row['snapshot']['players']:
    player_id = player['playerId']['value']
    
    # Find the index of the player in player_metrics_df
    if player_id in player_pf['playerID'].values:
        # Get the index of the player to update their metrics
        player_index = player_pf[player_pf['playerID'] == player_id].index[0]

        # Update Assists and TotalScore in player_metrics_df
        player_pf.at[player_index, 'Assists'] = player['assists']
        player_pf.at[player_index, 'TotalScore'] = player['scores']['combatScore']['totalScore']

# %% [markdown]
# #### Agent Mapping

# %%
agentmap = {'ADD6443A-41BD-E414-F6AD-E58D267F4E95': 'Jett',
 'A3BFB853-43B2-7238-A4F1-AD90E9E46BCC': 'Reyna',
 'F94C3B30-42BE-E959-889C-5AA313DBA261': 'Raze',
 '7F94D92C-4234-0A36-9646-3A87EB8B5C89': 'Yoru',
 'EB93336A-449B-9C1B-0A54-A891F7921D69': 'Phoenix',
 'BB2A4828-46EB-8CD1-E765-15848195D751': 'Neon',
 '5F8D3A7F-467B-97F3-062C-13ACF203C006': 'Breach',
 '6F2A04CA-43E0-BE17-7F36-B3908627744D': 'Skye',
 '320B2A48-4D9B-A075-30F1-1F93A9B638FA': 'Sova',
 '601DBBE7-43CE-BE57-2A40-4ABD24953621': 'Kayo',
 '1E58DE9C-4950-5125-93E9-A0AEE9F98746': 'Killjoy',
 '117ED9E3-49F3-6512-3CCF-0CADA7E3823B': 'Cypher',
 '569FDD95-4D10-43AB-CA70-79BECC718B46': 'Sage',
 '22697A3D-45BF-8DD7-4FEC-84A9E28C69D7': 'Chamber',
 '8E253930-4C05-31DD-1B6C-968525494517': 'Omen',
 '9F0D8BA9-4140-B941-57D3-A7AD57C6B417': 'Brimstone',
 '41FB69C1-4189-7B37-F117-BCAF1E96F1BF': 'Astra',
 '707EAB51-4836-F488-046A-CDA6BF494859': 'Viper',
 'DADE69B4-4F5A-8528-247B-219E5A1FACD6': 'Fade',
 '95B78ED7-4637-86D9-7E41-71BA8C293152': 'Harbor',
 'E370FA57-4757-3604-3648-499E1F642D3F': 'Gekko',
 'CC8B64C8-4B25-4FF9-6E7F-37B4DA43D235': 'Deadlock',
 '0E38B510-41A8-5780-5E8F-568B2A4F2D6C': 'Iso',
 '1DBF2EDD-4729-0984-3115-DAA5EED44993': 'Clove',
 'EFBA5359-4016-A1E5-7626-B1AE76895940': 'Vyse'}

# %%
filtered_df = raw_data[raw_data['configuration'].notna()]
agent = []

for player in filtered_df['configuration'].iloc[-1]['players']:
    account_id = player['accountId']['value']
    player_id = player['playerId']['value']
    display_name = player['displayName']
    selected_agent = player['selectedAgent']['fallback']['guid']
    
    agent.append({
        'accountId': account_id,
        'playerId': player_id,
        'displayName': display_name,
        'selectedAgent': selected_agent
    })

# Create a DataFrame
agent_df = pd.DataFrame(agent)

agent_df['AgentName'] = agent_df['selectedAgent'].map(agentmap)


player_pf = pd.merge(player_pf, agent_df, left_on='playerID', right_on='playerId')
player_pf = player_pf.drop(columns = ['selectedAgent','playerId'], axis=1)

# %% [markdown]
# ### player_pf

# %%
player_pf

# %%
import os
class PlayerPerformanceAggregator:
    
    def __init__(self, agg_file='player_performance_agg.xlsx'):
        """
        Initialize the PlayerPerformanceAggregator with the file path.
        """
        self.agg_file = agg_file
        self.agg_df = self._load_or_initialize_agg_df()
    
    def _load_or_initialize_agg_df(self):
        """
        Load the existing aggregate DataFrame or initialize a new one if it doesn't exist.
        """
        if os.path.exists(self.agg_file):
            # Load the existing aggregate Excel file if it exists
            agg_df = pd.read_excel(self.agg_file, index_col=0)
            print(f"Loaded existing aggregate data from {self.agg_file}")
        else:
            # Create an empty DataFrame with the relevant columns if the file doesn't exist
            agg_df = pd.DataFrame(columns=['accountId', 'games_played', 'kills', 'deaths', 'damage_dealt',
                                           'damage_taken', 'total_hits', 'headshots', 'Assists', 'TotalScore', 'agent_pool'])
            print(f"Created a new aggregate file at {self.agg_file}")
        return agg_df
    
    def _update_agent_pool(self, existing_pool, new_agent):
        """
        Update the agent pool by adding new agents to the list.
        
        :param existing_pool: The existing agent pool as a comma-separated string.
        :param new_agent: The new agent played by the player in the current game.
        :return: Updated agent pool as a comma-separated string.
        """
        if pd.isna(existing_pool):  # If no agents have been tracked yet
            agent_pool = {new_agent}
        else:
            agent_pool = set(existing_pool.split(','))  # Convert existing pool into a set for uniqueness
            agent_pool.add(new_agent)  # Add the new agent
        
        return ','.join(sorted(agent_pool))  # Return the updated agent pool as a sorted comma-separated string

    def aggregate_player_data(self, player_pf):
        """
        Aggregate the player_pf data into the existing aggregate DataFrame, updating the agent pool.
        
        :param player_pf: DataFrame containing player performance data.
        """
        # Columns to aggregate (skipping accountId, displayName, and AgentName)
        agg_columns = ['kills', 'deaths', 'damage_dealt', 'damage_taken', 
                       'total_hits', 'headshots', 'Assists', 'TotalScore']

        # Loop through each player in the new player performance data (player_pf)
        for index, row in player_pf.iterrows():
            account_id = row['accountId']
            agent_name = row['AgentName']  # The agent the player used in this game
            
            # Check if the player already exists in the aggregated DataFrame
            if account_id in self.agg_df['accountId'].values:
                # Update the player's cumulative sum and games played
                self.agg_df.loc[self.agg_df['accountId'] == account_id, 'games_played'] += 1
                
                for col in agg_columns:
                    self.agg_df.loc[self.agg_df['accountId'] == account_id, col] += row[col]
                
                # Update the agent pool for the player
                current_pool = self.agg_df.loc[self.agg_df['accountId'] == account_id, 'agent_pool'].values[0]
                updated_pool = self._update_agent_pool(current_pool, agent_name)
                self.agg_df.loc[self.agg_df['accountId'] == account_id, 'agent_pool'] = updated_pool
            else:
                # Add a new entry for the player (only aggregate relevant columns and add new agent to the pool)
                print(self.agg_df.columns)
                new_row = pd.Series([account_id, 1] + row[agg_columns].tolist() + [agent_name], index=self.agg_df.columns)
                self.agg_df = pd.concat([self.agg_df, pd.DataFrame([new_row])], ignore_index=True)

    
    def _calculate_averages(self):
        """
        Calculate the averages for performance columns and add them to the DataFrame.
        """
        avg_columns = ['kills', 'deaths', 'damage_dealt', 'damage_taken', 
                       'total_hits', 'headshots', 'Assists', 'TotalScore']
        
        # Calculate average columns by dividing the cumulative values by games_played
        for col in avg_columns:
            avg_col_name = f'avg_{col}'
            self.agg_df[avg_col_name] = self.agg_df[col] / self.agg_df['games_played']
    
    def save_agg_df(self):
        """
        Save the aggregated DataFrame back to the Excel file.
        """
        # Before saving, calculate the averages
        self._calculate_averages()

        try:
            self.agg_df.to_excel(self.agg_file)
            print(f"Aggregated data saved to {self.agg_file}")
        except Exception as e:
            print(f"Error saving data to Excel: {e}")

# Example usage:
# Assuming `player_pf` is the player performance DataFrame you get from GameDataCleaner

def example_usage(player_pf):
    # Create an instance of PlayerPerformanceAggregator
    aggregator = PlayerPerformanceAggregator()
    
    # Aggregate the new player performance data
    aggregator.aggregate_player_data(player_pf)
    
    # Save the updated aggregated data
    aggregator.save_agg_df()

# Example test case (assuming `player_pf` is the DataFrame you are passing):
# Call `example_usage(player_pf)` after you get `player_pf` from GameDataCleaner
example_usage(player_pf)
